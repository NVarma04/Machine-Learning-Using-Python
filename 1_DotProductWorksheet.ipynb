# %%
import numpy as np
z=0
n=int(input('Enter the size of array: '))
for i in range(n):
  a=np.array(eval(input("Enter array 1 : ")))
  b=np.array(eval(input("Enter array 2 : ")))
  z=z+np.dot(a,b)
print('Result of Dot Product is {0}.'.format(z))
# Out:
# Enter the size of array: 3
# Enter array 1 : 1
# Enter array 2 : 2
# Enter array 1 : 3
# Enter array 2 : -1
# Enter array 1 : 0
# Enter array 2 : -9
# Result of Dot Product is -1.
